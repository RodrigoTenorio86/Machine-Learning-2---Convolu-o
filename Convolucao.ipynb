# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoTenorio86/Machine_Learning_2_Convolucao/blob/master/Convolucao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
# !pip install opencv-python==3.1.0.4
# Out:
# Requirement already satisfied: opencv-python==3.1.0.4 in /usr/local/lib/python3.6/dist-packages (3.1.0.4)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==3.1.0.4) (1.18.4)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np
from scipy import misc

# %% [markdown]
# ## Teste de Filtro para Edifício

# %%
img = mpimg.imread('/content/veiculo_vermelho.png')
print(img)

# %%
imgplot = plt.imshow(img)

# %%
plt.grid(False)
plt.gray()
plt.axis('off')
plt.imshow(img)
plt.show()

# %%
i_transformed = np.copy(img)
size_x = i_transformed.shape[0]
size_y = i_transformed.shape[1]

# %% [markdown]
# ## Filtro A

# %%
# Este filtro detecta bem as arestas
# Cria uma convolução que só passa por arestas vivas e linhas retas

filter = [ [0,1,0], [0,1,0], [1, 0, 1]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      convolution = 0.0
      convolution = convolution + (img[x - 1, y-1] * filter[0][0])
      convolution = convolution + (img[x, y-1] * filter[0][1])
      convolution = convolution + (img[x + 1, y-1] * filter[0][2])
      convolution = convolution + (img[x-1, y] * filter[1][0])
      convolution = convolution + (img[x, y] * filter[1][1])
      convolution = convolution + (img[x+1, y] * filter[1][2])
      convolution = convolution + (img[x-1, y+1] * filter[2][0])
      convolution = convolution + (img[x, y+1] * filter[2][1])
      convolution = convolution + (img[x+1, y+1] * filter[2][2])
      convolution = convolution * weight
      if np.any((convolution<0)):
            convolution=0
      if np.any((convolution>255)):
            convolution=255
      i_transformed[x, y] = convolution

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
#plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Filtro B

# %%
# Este filtro detecta bem as arestas
# Cria uma convolução que só passa por arestas vivas e linhas retas

filter = [ [1,0,1], [0,1,0], [1,0,1]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      convolution = 0.0
      convolution = convolution + (img[x - 1, y-1] * filter[0][0])
      convolution = convolution + (img[x, y-1] * filter[0][1])
      convolution = convolution + (img[x + 1, y-1] * filter[0][2])
      convolution = convolution + (img[x-1, y] * filter[1][0])
      convolution = convolution + (img[x, y] * filter[1][1])
      convolution = convolution + (img[x+1, y] * filter[1][2])
      convolution = convolution + (img[x-1, y+1] * filter[2][0])
      convolution = convolution + (img[x, y+1] * filter[2][1])
      convolution = convolution + (img[x+1, y+1] * filter[2][2])
      convolution = convolution * weight
      if np.any((convolution<0)):
            convolution=0
      if np.any((convolution>255)):
            convolution=255
      i_transformed[x, y] = convolution

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
#plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Filtro C

# %%
# Este filtro detecta bem as arestas
# Cria uma convolução que só passa por arestas vivas e linhas retas

filter = [ [1,1,1], [0,1,0], [1,1,1]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      convolution = 0.0
      convolution = convolution + (img[x - 1, y-1] * filter[0][0])
      convolution = convolution + (img[x, y-1] * filter[0][1])
      convolution = convolution + (img[x + 1, y-1] * filter[0][2])
      convolution = convolution + (img[x-1, y] * filter[1][0])
      convolution = convolution + (img[x, y] * filter[1][1])
      convolution = convolution + (img[x+1, y] * filter[1][2])
      convolution = convolution + (img[x-1, y+1] * filter[2][0])
      convolution = convolution + (img[x, y+1] * filter[2][1])
      convolution = convolution + (img[x+1, y+1] * filter[2][2])
      convolution = convolution * weight
      if np.any((convolution<0)):
            convolution=0
      if np.any((convolution>255)):
            convolution=255
      i_transformed[x, y] = convolution

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Filtro D

# %%
# Este filtro detecta bem as arestas
# Cria uma convolução que só passa por arestas vivas e linhas retas

filter = [ [0,0,0], [0,1,0], [0,0,0]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      convolution = 0.0
      convolution = convolution + (img[x - 1, y-1] * filter[0][0])
      convolution = convolution + (img[x, y-1] * filter[0][1])
      convolution = convolution + (img[x + 1, y-1] * filter[0][2])
      convolution = convolution + (img[x-1, y] * filter[1][0])
      convolution = convolution + (img[x, y] * filter[1][1])
      convolution = convolution + (img[x+1, y] * filter[1][2])
      convolution = convolution + (img[x-1, y+1] * filter[2][0])
      convolution = convolution + (img[x, y+1] * filter[2][1])
      convolution = convolution + (img[x+1, y+1] * filter[2][2])
      convolution = convolution * weight
      if np.any((convolution<0)):
            convolution=0
      if np.any((convolution>255)):
            convolution=255
      i_transformed[x, y] = convolution

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Teste de Filtro para Edifício

# %%
img = mpimg.imread('/content/edificio.png')
print(img)

# %%
imgplot = plt.imshow(img)

# %%
plt.grid(False)
plt.gray()
plt.axis('off')
plt.imshow(img)
plt.show()

# %%
i_transformed = np.copy(img)
size_x = i_transformed.shape[0]
size_y = i_transformed.shape[1]

# %% [markdown]
# ## Filtro A

# %%
filter = [ [0,1,0], [0,1,0], [1, 0, 1]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      convolution = 0.0
      convolution = convolution + (img[x - 1, y-1] * filter[0][0])
      convolution = convolution + (img[x, y-1] * filter[0][1])
      convolution = convolution + (img[x + 1, y-1] * filter[0][2])
      convolution = convolution + (img[x-1, y] * filter[1][0])
      convolution = convolution + (img[x, y] * filter[1][1])
      convolution = convolution + (img[x+1, y] * filter[1][2])
      convolution = convolution + (img[x-1, y+1] * filter[2][0])
      convolution = convolution + (img[x, y+1] * filter[2][1])
      convolution = convolution + (img[x+1, y+1] * filter[2][2])
      convolution = convolution * weight
      if np.any((convolution<0)):
            convolution=0
      if np.any((convolution>255)):
            convolution=255
      i_transformed[x, y] = convolution

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
#plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Filtro B

# %%
filter = [ [1,0,1], [0,1,0], [1, 0, 1]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      convolution = 0.0
      convolution = convolution + (img[x - 1, y-1] * filter[0][0])
      convolution = convolution + (img[x, y-1] * filter[0][1])
      convolution = convolution + (img[x + 1, y-1] * filter[0][2])
      convolution = convolution + (img[x-1, y] * filter[1][0])
      convolution = convolution + (img[x, y] * filter[1][1])
      convolution = convolution + (img[x+1, y] * filter[1][2])
      convolution = convolution + (img[x-1, y+1] * filter[2][0])
      convolution = convolution + (img[x, y+1] * filter[2][1])
      convolution = convolution + (img[x+1, y+1] * filter[2][2])
      convolution = convolution * weight
      if np.any((convolution<0)):
            convolution=0
      if np.any((convolution>255)):
            convolution=255
      i_transformed[x, y] = convolution

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
#plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Filtro C

# %%
filter = [ [1,1,1], [0,1,0], [1, 1, 1]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      convolution = 0.0
      convolution = convolution + (img[x - 1, y-1] * filter[0][0])
      convolution = convolution + (img[x, y-1] * filter[0][1])
      convolution = convolution + (img[x + 1, y-1] * filter[0][2])
      convolution = convolution + (img[x-1, y] * filter[1][0])
      convolution = convolution + (img[x, y] * filter[1][1])
      convolution = convolution + (img[x+1, y] * filter[1][2])
      convolution = convolution + (img[x-1, y+1] * filter[2][0])
      convolution = convolution + (img[x, y+1] * filter[2][1])
      convolution = convolution + (img[x+1, y+1] * filter[2][2])
      convolution = convolution * weight
      if np.any((convolution<0)):
            convolution=0
      if np.any((convolution>255)):
            convolution=255
      i_transformed[x, y] = convolution

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
#plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Filtro D

# %%
filter = [ [0,0,0], [0,1,0], [0, 0, 0]]
weight  = 1

# %%
for x in range(1,size_x-1):
  for y in range(1,size_y-1):
      convolution = 0.0
      convolution = convolution + (img[x - 1, y-1] * filter[0][0])
      convolution = convolution + (img[x, y-1] * filter[0][1])
      convolution = convolution + (img[x + 1, y-1] * filter[0][2])
      convolution = convolution + (img[x-1, y] * filter[1][0])
      convolution = convolution + (img[x, y] * filter[1][1])
      convolution = convolution + (img[x+1, y] * filter[1][2])
      convolution = convolution + (img[x-1, y+1] * filter[2][0])
      convolution = convolution + (img[x, y+1] * filter[2][1])
      convolution = convolution + (img[x+1, y+1] * filter[2][2])
      convolution = convolution * weight
      if np.any((convolution<0)):
            convolution=0
      if np.any((convolution>255)):
            convolution=255
      i_transformed[x, y] = convolution

# %%
plt.gray()
plt.grid(False)
plt.imshow(i_transformed)
#plt.axis('off')
plt.show()
